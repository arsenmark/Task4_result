# %%
import os

import rasterio
from rasterio.plot import reshape_as_image
import rasterio.mask
from rasterio.features import rasterize

import pandas as pd
import geopandas as gpd
from shapely.geometry import mapping, Point, Polygon
from shapely.ops import cascaded_union

import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
raster_path = "T36UXV_20200406T083559_TCI_10m.jp2"

with rasterio.open(raster_path) as src:
    raster_img = src.read()
    raster_meta = src.meta

# %%
raster_meta
# Out:
# {'driver': 'JP2OpenJPEG',
#  'dtype': 'uint8',
#  'nodata': None,
#  'width': 10980,
#  'height': 10980,
#  'count': 3,
#  'crs': CRS.from_epsg(32636),
#  'transform': Affine(10.0, 0.0, 600000.0,
#         0.0, -10.0, 5500020.0)}

# %%
raster_img = reshape_as_image(raster_img)

plt.figure(figsize=(10,10))
plt.imshow(raster_img[0])

# %%
plt.figure(figsize=(10,10))
plt.imshow(raster_img[1])

# %%
plt.figure(figsize=(10,10))
plt.imshow(raster_img[2])

# %%
train_df = gpd.read_file("Masks_T36UXV_20190427.shp")
print(len(train_df))
train_df.head(30)
# Out:
# 936
#       id  Data  Code                Descriptio Comments  \
# 0   None  None   2.0            branch of tree     None
# 1   None  None   1.0           color+ feathers     None
# 2   None  None   2.0            brahch of tree     None
# 3   None  None   1.0           color+ feathers     None
# 4   None  None   1.0           color+ feathers     None
# 5   None  None   1.0           color+ feathers     None
# 6   None  None   1.0           color+ feathers     None
# 7   None  None   2.0            branch of tree     None
# 8   None  None   2.0            branch of tree     None
# 9   None  None   1.0           color+ feathers     None
# 10  None  None   1.0           color+ feathers     None
# 11  None  None   2.0            branch of tree     None
# 12  None  None   1.0           color+ feathers     None
# 13  None  None   2.0            branch of tree     None
# 14  None  None   2.0            branch of tree     None
# 15  None  None   1.0           color+ feathers     None
# 16  None  None   2.0            branch of tree     None
# 17  None  None   2.0            branch of tree     None
# 18  None  None   1.0           color+ feathers     None
# 19  None  None   1.0           color+ feathers     None
# 20  None  None   1.0           color+ feathers     None
# 21  None  None   1.0  color+ feathers + branch     None
# 22  None  None   2.0            branch of tree     None
# 23  None  None   1.0          color + feathers     None
# 24  None  None   1.0          color + feathers     None
# 25  None  None   2.0            branch of tree     None
# 26  None  None   1.0           color+ feathers     None
# 27  None  None   2.0            branch of tree     None
# 28  None  None   5.0  branch + color+ feathers     None
# 29  None  None   5.0  branch + color+ feathers     None
#
#                      Image                                           geometry
# 0   T36UXV_20190427T083601  POLYGON ((35.62916 49.60293, 35.63015 49.60163...
# 1   T36UXV_20190427T083601  POLYGON ((35.65070 49.60254, 35.65248 49.60301...
# 2   T36UXV_20190427T083601  POLYGON ((35.63023 49.60826, 35.62960 49.60920...
# 3   T36UXV_20190427T083601  POLYGON ((35.62033 49.60905, 35.62064 49.60968...
# 4   T36UXV_20190427T083601  POLYGON ((35.60455 49.61078, 35.60597 49.61228...
# 5   T36UXV_20190427T083601  POLYGON ((35.60783 49.59848, 35.60736 49.59897...
# 6   T36UXV_20190427T083601  POLYGON ((35.59871 49.60834, 35.59859 49.60857...
# 7   T36UXV_20190427T083601  POLYGON ((35.58841 49.60416, 35.58869 49.60433...
# 8   T36UXV_20190427T083601  POLYGON ((35.59142 49.60402, 35.59172 49.60377...
# 9   T36UXV_20190427T083601  POLYGON ((35.58347 49.61376, 35.58220 49.61355...
# 10                    None  POLYGON ((35.57007 49.62141, 35.57098 49.62182...
# 11  T36UXV_20190427T083601  POLYGON ((35.55090 49.62171, 35.54982 49.62101...
# 12  T36UXV_20190427T083601  POLYGON ((35.54943 49.62667, 35.54886 49.62631...
# 13  T36UXV_20190427T083601  POLYGON ((35.52417 49.63302, 35.52467 49.63285...
# 14  T36UXV_20190427T083601  POLYGON ((35.52236 49.63346, 35.52273 49.63334...
# 15  T36UXV_20190427T083601  POLYGON ((35.53280 49.61315, 35.53328 49.61339...
# 16  T36UXV_20190427T083601  POLYGON ((35.54303 49.61090, 35.54356 49.61104...
# 17  T36UXV_20190427T083601  POLYGON ((35.51653 49.62164, 35.51797 49.62166...
# 18  T36UXV_20190427T083601  POLYGON ((35.51396 49.61756, 35.51468 49.61753...
# 19  T36UXV_20190427T083601  POLYGON ((35.51095 49.60982, 35.51043 49.61037...
# 20  T36UXV_20190427T083601  POLYGON ((35.50449 49.61763, 35.50520 49.61838...
# 21  T36UXV_20190427T083601  POLYGON ((35.50927 49.58700, 35.51030 49.58792...
# 22  T36UXV_20190427T083601  POLYGON ((35.51765 49.59308, 35.51839 49.59294...
# 23  T36UXV_20190427T083601  POLYGON ((35.51520 49.59559, 35.51386 49.59535...
# 24  T36UXV_20190427T083601  POLYGON ((35.47223 49.62114, 35.47283 49.62137...
# 25  T36UXV_20190427T083601  POLYGON ((35.47741 49.61510, 35.47793 49.61502...
# 26  T36UXV_20190427T083601  POLYGON ((35.48175 49.61053, 35.48266 49.61091...
# 27  T36UXV_20190427T083601  POLYGON ((35.48528 49.60734, 35.48563 49.60726...
# 28  T36UXV_20190427T083601  POLYGON ((35.45042 49.58960, 35.45058 49.58996...
# 29  T36UXV_20190427T083601  POLYGON ((35.45923 49.59117, 35.45988 49.59145...

# %%
src = rasterio.open(raster_path,'r')
failed = []
for num, row in train_df.iterrows():
    try:
        masked_image, out_transform = rasterio.mask.mask(src, [mapping(row['gemetry'])], crop = True, nodata=0)
    except:
        failed.append(num)
        
print("Rasterio failed to mask {} files".format(len(failed)))
# Out:
# Rasterio failed to mask 936 files

# %%
train_df['geometry'][0].exterior.coords.xy
# Out:
# (array('d', [35.62916346617293, 35.63014960535702, 35.631175190108465, 35.631214635675825, 35.630031268654925, 35.62888734720139, 35.62813788142149, 35.62774342574785, 35.62813788142149, 35.62916346617293]),
#  array('d', [49.602931546762534, 49.60162984303954, 49.60080148612491, 49.59981534694083, 49.6001703570471, 49.60111705066382, 49.60214263541526, 49.60289210119517, 49.60312877459935, 49.602931546762534]))

# %%
train_df = gpd.read_file("Masks_T36UXV_20190427.shp")

train_df = train_df[train_df.geometry.notnull()]

train_df.crs = {'init' :"epsg:4326"}

train_df = train_df.to_crs({'init' : raster_meta['crs']['init']})
# Out:
# /usr/local/lib/python3.7/dist-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /usr/local/lib/python3.7/dist-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
src = rasterio.open(raster_path, 'r', driver="JP2OpenJPEG")
outfolder = "article"
os.makedirs(outfolder, exist_ok=True)
failed = []
for num, row in train_df.iterrows():
    try:
        masked_image, out_transform = rasterio.mask.mask(src, [mapping(row['geometry'])], crop=True, nodata=0)
        img_image = reshape_as_image(masked_image)
        img_path = os.path.join(outfolder, str(row['Field_Id']) + '.png')
        img_image = cv2.cvtColor(img_image, cv2.COLOR_RGB2BGR)
        cv2.imwrite(img_path, img_image)
    except Exception as e:
#         print(e)
        failed.append(num)
print("Rasterio failed to mask {} files".format(len(failed)))
# Out:
# Rasterio failed to mask 935 files

# %%
# rasterize works with polygons that are in image coordinate system

def poly_from_utm(polygon, transform):
    poly_pts = []
    
    # make a polygon from multipolygon
    poly = cascaded_union(polygon)
    for i in np.array(poly.exterior.coords):
        
        # transfrom polygon to image crs, using raster meta
        poly_pts.append(~transform * tuple(i))
        
    # make a shapely Polygon object
    new_poly = Polygon(poly_pts)
    return new_poly

# creating binary mask for field/not_filed segmentation.

poly_shp = []
im_size = (src.meta['height'], src.meta['width'])
for num, row in train_df.iterrows():
    if row['geometry'].geom_type == 'Polygon':
        poly = poly_from_utm(row['geometry'], src.meta['transform'])
        poly_shp.append(poly)
    else:
        for p in row['geometry']:
            poly = poly_from_utm(p, src.meta['transform'])
            poly_shp.append(poly)

mask = rasterize(shapes=poly_shp,
                 out_shape=im_size)

# plotting the mask

plt.figure(figsize=(15,15))
plt.imshow(mask)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: ShapelyDeprecationWarning: The 'cascaded_union()' function is deprecated. Use 'unary_union()' instead.
#   import sys

# %%
bin_mask_meta = src.meta.copy()
bin_mask_meta.update({'count': 1})
with rasterio.open("train.jp2", 'w', **bin_mask_meta) as dst:
    dst.write(mask * 255, 1)
